# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso
import pickle   # save in arbitrary format

# %%
df = pd.read_csv('cars.csv')
X= df[['cylinders','horsepower','weight']]
target = df.mpg
model = LinearRegression()
model.fit(X,target)
print(model.coef_)
# Out:
# [-1.11439132  0.09151962 -0.00850185]

# %%
pickle.dump(model,open('linreg.p','wb'))

# %% [markdown]
# Restart Kernel here

# %%
import pickle
model = pickle.load(open('linreg.p','rb'))

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
cyl = 9
horse = 300
weight = 2000
model.predict([[cyl,horse,weight]])
# Out:
# array([47.14413162])

# %% [markdown]
# ## stuff I did earlier in the morning

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0  18.0          8         307.0       130.0  3504.0          12.0     70
# 1  15.0          8         350.0       165.0  3693.0          11.5     70
# 2  18.0          8         318.0       150.0  3436.0          11.0     70
# 3  16.0          8         304.0       150.0  3433.0          12.0     70
# 4  17.0          8         302.0       140.0  3449.0          10.5     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
sns.pairplot(df)

# %%
df['displx']=df['displacement']**(-1)

# %%
df['displacement'].head(),df['displx'].head()
# Out:
# (0    307.0
#  1    350.0
#  2    318.0
#  3    304.0
#  4    302.0
#  Name: displacement, dtype: float64, 0    0.003257
#  1    0.002857
#  2    0.003145
#  3    0.003289
#  4    0.003311
#  Name: displx, dtype: float64)

# %%
sns.scatterplot(x=df['displx'],y=df['mpg'])

# %%
df1=df[~df.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
X,y = df1[['displx','mpg']].values.T

# %%
reg = Lasso(alpha=0.1)

# %%
reg.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-7bea1b844d2d> in <module>()
# ----> 1 reg.fit(X,y)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py in fit(self, X, y, check_input)
#     711             X, y = check_X_y(X, y, accept_sparse='csc',
#     712                              order='F', dtype=[np.float64, np.float32],
# --> 713                              copy=X_copied, multi_output=True, y_numeric=True)
#     714             y = check_array(y, order='F', copy=False, dtype=X.dtype.type,
#     715                             ensure_2d=False)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     550                     "Reshape your data either using array.reshape(-1, 1) if "
#     551                     "your data has a single feature or array.reshape(1, -1) "
# --> 552                     "if it contains a single sample.".format(array))
#     553
#     554         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.00325733 0.00285714 0.00314465 0.00328947 0.00331126 0.002331
#  0.00220264 0.00227273 0.0021978  0.0025641  0.00261097 0.00294118
#  0.0025     0.0021978  0.00884956 0.00505051 0.00502513 0.005
#  0.01030928 0.01030928 0.00909091 0.00934579 0.00961538 0.00826446
#  0.00502513 0.00277778 0.00325733 0.00314465 0.00328947 0.01030928
#  0.00714286 0.00884956 0.00431034 0.00444444 0.004      0.004
#  0.00431034 0.00285714 0.0025     0.002849   0.00314465 0.00261097
#  0.0025     0.0025     0.00387597 0.00714286 0.004      0.004
#  0.00819672 0.00862069 0.01265823 0.01136364 0.01408451 0.01388889
#  0.01030928 0.01098901 0.00884956 0.01025641 0.01030928 0.00714286
#  0.00819672 0.00285714 0.0025     0.00314465 0.002849   0.00328947
#  0.002331   0.00285714 0.00285714 0.0025     0.01428571 0.00328947
#  0.00325733 0.00331126 0.00314465 0.00826446 0.00826446 0.00833333
#  0.01041667 0.00819672 0.01030928 0.00833333 0.01020408 0.01030928
#  0.00285714 0.00328947 0.00285714 0.00331126 0.00314465 0.002331
#  0.0025     0.002849   0.00314465 0.00227273 0.0021978  0.00277778
#  0.00444444 0.004      0.00431034 0.004      0.00505051 0.01030928
#  0.0025     0.0025     0.00277778 0.00285714 0.00431034 0.01030928
#  0.00714286 0.00925926 0.01428571 0.00819672 0.00645161 0.01020408
